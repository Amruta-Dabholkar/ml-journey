# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a DataFrame

# %%
data = {
    'Name':['John','Anna','Petter','Linda'],
    'Age':[28,34,29,42],
    'City': ['New York','Paris','Berlin','London'],
    'Salary':[65000,70000,62000,85000]
}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2  Petter   29    Berlin   62000
# 3   Linda   42    London   85000

# %%
data_list = [
    ['John',28,'New York',65000],
    ['Anna',34,'Paris',70000],
    ['Pette',29,'Paris',62000],
    ['Linda',42,'London',85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','Age','City','Salary']
df2 = pd.DataFrame(data_list,columns=columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Pette   29     Paris   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and Indexing Of Columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Pette   29     Paris   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Pette
# 3    Linda
# Name: Name, dtype: object

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2       Paris
# 3      London
# Name: City, dtype: object

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Pette     Paris
# 3  Linda    London

# %% [markdown]
# Creating a new column

# %%
df2["Designation"] = ["Doctor","Engineer","Doctor","Engineer"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Pette   29     Paris   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %% [markdown]
# Removing a column

# %%
df2.drop('Designation',axis = 1 ,inplace = True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Pette   29     Paris   62000
# 3  Linda   42    London   85000

# %%
df2.drop(['City','Name'],axis = 1 ,inplace = True)

# %%
df2
# Out:
#    Age  Salary
# 0   28   65000
# 1   34   70000
# 2   29   62000
# 3   42   85000

# %%
df2.drop(0,axis = 0 )
# Out:
#    Age  Salary
# 1   34   70000
# 2   29   62000
# 3   42   85000

# %% [markdown]
# Selecting Rows

# %%
df2.loc[0]
# Out:
# Age          28
# Salary    65000
# Name: 0, dtype: int64

# %%
df2.loc[[0,1]]
# Out:
#    Age  Salary
# 0   28   65000
# 1   34   70000

# %%
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# Selecting Subset of Rows and Columns

# %%
df.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#      Name  Age
# 2  Petter   29
# 3   Linda   42

# %% [markdown]
# Conditional Selection

# %%
data_list = [
    ['John',28,'New York',65000],
    ['Anna',34,'Paris',70000],
    ['Pette',29,'Paris',62000],
    ['Linda',42,'London',85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','Age','City','Salary']
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Pette   29     Paris   62000
# 3  Linda   42    London   85000

# %%
#age>30
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#age>30 & belongs to paris
df2[(df2['Age']>30) & (df2['City']=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
